# %%
import pandas as pd
sales = pd.read_csv("Data/sales.csv",index_col='State')
sales
# Out:
#             Total Expenses         Product  Sales   Market Size  Profit  \
# State
# California            63.0        Amaretto  109.0  Major Market  -131.0
# California            55.0       Green Tea  201.0  Major Market    88.0
# California           143.0     Caffe Mocha  289.0  Major Market    25.0
# California           113.0  Decaf Espresso  576.0  Major Market   216.0
# California            37.0       Chamomile  247.0  Major Market   148.0
# ...                    ...             ...    ...           ...     ...
# Wisconsin             34.0      Darjeeling   90.0  Small Market    20.0
# Wisconsin             36.0      Darjeeling  113.0  Small Market    31.0
# Wisconsin             86.0       Earl Grey  150.0  Small Market     1.0
# Wisconsin             79.0       Earl Grey  131.0  Small Market    -3.0
# Wisconsin             87.0       Earl Grey  165.0  Small Market     4.0
#
#              Market  Marketing Product Type  Inventory     Type
# State
# ...

# %%
sales.Market == 'West'
# Out:
# State
# California     True
# California     True
# California     True
# California     True
# California     True
#               ...
# Wisconsin     False
# Wisconsin     False
# Wisconsin     False
# Wisconsin     False
# Wisconsin     False
# Name: Market, Length: 4241, dtype: bool

# %%
sales.loc[sales.Market == 'West']
# Out:
#             Total Expenses         Product  Sales   Market Size  Profit  \
# State
# California            63.0        Amaretto  109.0  Major Market  -131.0
# California            55.0       Green Tea  201.0  Major Market    88.0
# California           143.0     Caffe Mocha  289.0  Major Market    25.0
# California           113.0  Decaf Espresso  576.0  Major Market   216.0
# California            37.0       Chamomile  247.0  Major Market   148.0
# ...                    ...             ...    ...           ...     ...
# Washington            35.0       Earl Grey  106.0  Small Market    28.0
# Washington            32.0       Earl Grey   89.0  Small Market    28.0
# Washington            36.0       Earl Grey  120.0  Small Market    46.0
# Washington            36.0       Earl Grey  120.0  Small Market    46.0
# Washington            26.0     Caffe Latte  109.0  Small Market    47.0
#
#            Market  Marketing Product Type  Inventory     Type
# State
# ...

# %% [markdown]
# # combining filters

# %%
sales.loc[(sales.Market == 'West') & (sales.Sales > 200)]
# Out:
#             Total Expenses            Product  Sales   Market Size  Profit  \
# State
# California            55.0          Green Tea  201.0  Major Market    88.0
# California           143.0        Caffe Mocha  289.0  Major Market    25.0
# California           113.0     Decaf Espresso  576.0  Major Market   216.0
# California            37.0          Chamomile  247.0  Major Market   148.0
# California            99.0              Lemon  582.0  Major Market   291.0
# ...                    ...                ...    ...           ...     ...
# Washington           114.0  Decaf Irish Cream  239.0  Small Market    24.0
# Washington            69.0          Chamomile  289.0  Small Market   105.0
# Washington            75.0          Chamomile  347.0  Small Market   179.0
# Washington            62.0          Chamomile  273.0  Small Market   135.0
# Washington            64.0          Chamomile  275.0  Small Market   135.0
#
# ...

# %%
sales.loc[(sales.Market == 'West') | (sales.Profit > 100)]
# Out:
#             Total Expenses            Product  Sales   Market Size  Profit  \
# State
# California            63.0           Amaretto  109.0  Major Market  -131.0
# California            55.0          Green Tea  201.0  Major Market    88.0
# California           143.0        Caffe Mocha  289.0  Major Market    25.0
# California           113.0     Decaf Espresso  576.0  Major Market   216.0
# California            37.0          Chamomile  247.0  Major Market   148.0
# ...                    ...                ...    ...           ...     ...
# Washington            36.0          Earl Grey  120.0  Small Market    46.0
# Washington            36.0          Earl Grey  120.0  Small Market    46.0
# Washington            26.0        Caffe Latte  109.0  Small Market    47.0
# Wisconsin             55.0  Decaf Irish Cream  229.0  Small Market   101.0
# Wisconsin             45.0          Chamomile  201.0  Small Market   109.0
#
# ...

# %%
sales.loc[sales.Product.isin(['Amaretto'])]
# Out:
#             Total Expenses   Product  Sales   Market Size  Profit   Market  \
# State
# California            63.0  Amaretto  109.0  Major Market  -131.0     West
# California            72.0  Amaretto   87.0  Major Market  -139.0     West
# California            63.0  Amaretto  117.0  Major Market  -113.0     West
# California            59.0  Amaretto  116.0  Major Market   -56.0     West
# California            55.0  Amaretto  141.0  Major Market   -40.0     West
# ...                    ...       ...    ...           ...     ...      ...
# Wisconsin             54.0  Amaretto  135.0  Small Market    24.0  Central
# Wisconsin             51.0  Amaretto  132.0  Small Market    26.0  Central
# Wisconsin             54.0  Amaretto  127.0  Small Market    16.0  Central
# Wisconsin             56.0  Amaretto  133.0  Small Market    18.0  Central
# Wisconsin             58.0  Amaretto  155.0  Small Market    33.0  Central
#
#             Marketing Product Type  Inventory     Type
# ...

# %%
sales
# Out:
#             Total Expenses         Product  Sales   Market Size  Profit  \
# State
# California            63.0        Amaretto  109.0  Major Market  -131.0
# California            55.0       Green Tea  201.0  Major Market    88.0
# California           143.0     Caffe Mocha  289.0  Major Market    25.0
# California           113.0  Decaf Espresso  576.0  Major Market   216.0
# California            37.0       Chamomile  247.0  Major Market   148.0
# ...                    ...             ...    ...           ...     ...
# Wisconsin             34.0      Darjeeling   90.0  Small Market    20.0
# Wisconsin             36.0      Darjeeling  113.0  Small Market    31.0
# Wisconsin             86.0       Earl Grey  150.0  Small Market     1.0
# Wisconsin             79.0       Earl Grey  131.0  Small Market    -3.0
# Wisconsin             87.0       Earl Grey  165.0  Small Market     4.0
#
#              Market  Marketing Product Type  Inventory     Type
# State
# ...

# %%
sales.loc[sales.Type.notnull()]
# Out:
#             Total Expenses         Product  Sales   Market Size  Profit  \
# State
# California            63.0        Amaretto  109.0  Major Market  -131.0
# California            55.0       Green Tea  201.0  Major Market    88.0
# California           143.0     Caffe Mocha  289.0  Major Market    25.0
# California           113.0  Decaf Espresso  576.0  Major Market   216.0
# California            37.0       Chamomile  247.0  Major Market   148.0
# ...                    ...             ...    ...           ...     ...
# Wisconsin             34.0      Darjeeling   90.0  Small Market    20.0
# Wisconsin             36.0      Darjeeling  113.0  Small Market    31.0
# Wisconsin             86.0       Earl Grey  150.0  Small Market     1.0
# Wisconsin             79.0       Earl Grey  131.0  Small Market    -3.0
# Wisconsin             87.0       Earl Grey  165.0  Small Market     4.0
#
#              Market  Marketing Product Type  Inventory     Type
# State
# ...

# %%
sales['Sales'] = 'Test'
sales
# Out:
#             Total Expenses         Product Sales   Market Size  Profit  \
# State
# California            63.0        Amaretto  Test  Major Market  -131.0
# California            55.0       Green Tea  Test  Major Market    88.0
# California           143.0     Caffe Mocha  Test  Major Market    25.0
# California           113.0  Decaf Espresso  Test  Major Market   216.0
# California            37.0       Chamomile  Test  Major Market   148.0
# ...                    ...             ...   ...           ...     ...
# Wisconsin             34.0      Darjeeling  Test  Small Market    20.0
# Wisconsin             36.0      Darjeeling  Test  Small Market    31.0
# Wisconsin             86.0       Earl Grey  Test  Small Market     1.0
# Wisconsin             79.0       Earl Grey  Test  Small Market    -3.0
# Wisconsin             87.0       Earl Grey  Test  Small Market     4.0
#
#              Market  Marketing Product Type  Inventory     Type
# State
# ...

# %% [markdown]
# # select multiple as array

# %%
sales.iloc[[1,2,3,4]]
# Out:
#             Total Expenses         Product Sales   Market Size  Profit Market  \
# State
# California            55.0       Green Tea  Test  Major Market    88.0   West
# California           143.0     Caffe Mocha  Test  Major Market    25.0   West
# California           113.0  Decaf Espresso  Test  Major Market   216.0   West
# California            37.0       Chamomile  Test  Major Market   148.0   West
#
#             Marketing Product Type  Inventory     Type
# State
# California         24          Tea      659.0  Regular
# California        109     Espresso      788.0  Regular
# California         81     Espresso     1744.0    Decaf
# California         26   Herbal Tea      809.0    Decaf

# %%
cols = ['Sales', 'Market Size']
indices = [0, 1, 10, 100]
#df = sales.loc[indices, cols] did not work cus indexes are not 0,1,10,100
