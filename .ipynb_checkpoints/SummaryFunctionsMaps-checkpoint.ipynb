# %%
import pandas as pd
sales = pd.read_csv("Data/sales.csv",index_col='State')
sales
# Out:
#             Total Expenses         Product  Sales   Market Size  Profit  \
# State
# California            63.0        Amaretto  109.0  Major Market  -131.0
# California            55.0       Green Tea  201.0  Major Market    88.0
# California           143.0     Caffe Mocha  289.0  Major Market    25.0
# California           113.0  Decaf Espresso  576.0  Major Market   216.0
# California            37.0       Chamomile  247.0  Major Market   148.0
# ...                    ...             ...    ...           ...     ...
# Wisconsin             34.0      Darjeeling   90.0  Small Market    20.0
# Wisconsin             36.0      Darjeeling  113.0  Small Market    31.0
# Wisconsin             86.0       Earl Grey  150.0  Small Market     1.0
# Wisconsin             79.0       Earl Grey  131.0  Small Market    -3.0
# Wisconsin             87.0       Earl Grey  165.0  Small Market     4.0
#
#              Market  Marketing Product Type  Inventory     Type
# State
# California     West         40       Coffee     2947.0  Regular
# California     West         24          Tea      659.0  Regular
# California     West        109     Espresso      788.0  Regular
# California     West         81     Espresso     1744.0    Decaf
# California     West         26   Herbal Tea      809.0    Decaf
# ...             ...        ...          ...        ...      ...
# Wisconsin   Central         11          Tea      458.0  Regular
# Wisconsin   Central         14          Tea      454.0  Regular
# Wisconsin   Central         57          Tea      506.0  Regular
# Wisconsin   Central         49          Tea      627.0  Regular
# Wisconsin   Central         58          Tea      513.0  Regular
#
# [4241 rows x 10 columns]

# %%
sales.Product.describe()
# Out:
# count            4241
# unique             13
# top       Caffe Mocha
# freq              480
# Name: Product, dtype: object

# %%
sales.Marketing.describe()
# Out:
# count    4241.000000
# mean       31.124499
# std        26.983618
# min         0.000000
# 25%        13.000000
# 50%        22.000000
# 75%        39.000000
# max       156.000000
# Name: Marketing, dtype: float64

# %%
sales['Total Expenses'].mean()
# Out:
# 53.98914582350165

# %%
sales.Product.unique()
# Out:
# array(['Amaretto', 'Green Tea', 'Caffe Mocha', 'Decaf Espresso',
#        'Chamomile', 'Lemon', 'Mint', 'Darjeeling', 'Earl Grey',
#        'Columbian', 'Caffe Latte', 'Decaf Irish Cream',
#        'Regular Espresso'], dtype=object)

# %% [markdown]
# # unique values

# %%
sales.Product.value_counts()
# Out:
# Caffe Mocha          480
# Lemon                479
# Columbian            478
# Decaf Espresso       407
# Chamomile            384
# Darjeeling           384
# Decaf Irish Cream    384
# Green Tea            288
# Earl Grey            288
# Caffe Latte          216
# Mint                 192
# Amaretto             189
# Regular Espresso      72
# Name: Product, dtype: int64

# %% [markdown]
# # maps

# %%
sales.Sales.map(lambda x:x + 34)
# Out:
# State
# California    143.0
# California    235.0
# California    323.0
# California    610.0
# California    281.0
#               ...
# Wisconsin     124.0
# Wisconsin     147.0
# Wisconsin     184.0
# Wisconsin     165.0
# Wisconsin     199.0
# Name: Sales, Length: 4241, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assume `reviews` is a DataFrame with a `points` column
review_points_mean = sales.Sales.mean()

# Define the mapping function using lambda
mapping_function = lambda p: p - review_points_mean

# Apply the mapping function to sales points column and save the result in a new column
sales['transformed_points'] = sales.Sales.map(mapping_function)

# Plot the original points against the transformed points
plt.scatter(sales.Sales, sales.transformed_points)
plt.xlabel('Original Points')
plt.ylabel('Transformed Points')
plt.title('Mapping Function Visualization')
plt.show()

# %% [markdown]
# # apply method

# %%
def change_rows(row):
    row.Marketing = row.Marketing + 33
    return row

sales.apply(change_rows,axis='columns')

#If we had called reviews.apply() with axis='index', then instead of passing a function to transform each row,
#we would need to give a function to transform each column.
# Out:
#             Total Expenses         Product  Sales   Market Size  Profit  \
# State
# California            63.0        Amaretto  109.0  Major Market  -131.0
# California            55.0       Green Tea  201.0  Major Market    88.0
# California           143.0     Caffe Mocha  289.0  Major Market    25.0
# California           113.0  Decaf Espresso  576.0  Major Market   216.0
# California            37.0       Chamomile  247.0  Major Market   148.0
# ...                    ...             ...    ...           ...     ...
# Wisconsin             34.0      Darjeeling   90.0  Small Market    20.0
# Wisconsin             36.0      Darjeeling  113.0  Small Market    31.0
# Wisconsin             86.0       Earl Grey  150.0  Small Market     1.0
# Wisconsin             79.0       Earl Grey  131.0  Small Market    -3.0
# Wisconsin             87.0       Earl Grey  165.0  Small Market     4.0
#
#              Market  Marketing Product Type  Inventory     Type  \
# State
# California     West         73       Coffee     2947.0  Regular
# California     West         57          Tea      659.0  Regular
# California     West        142     Espresso      788.0  Regular
# California     West        114     Espresso     1744.0    Decaf
# California     West         59   Herbal Tea      809.0    Decaf
# ...             ...        ...          ...        ...      ...
# Wisconsin   Central         44          Tea      458.0  Regular
# Wisconsin   Central         47          Tea      454.0  Regular
# Wisconsin   Central         90          Tea      506.0  Regular
# Wisconsin   Central         82          Tea      627.0  Regular
# Wisconsin   Central         91          Tea      513.0  Regular
#
#             transformed_points
# State
# California          -83.567351
# California            8.432649
# California           96.432649
# California          383.432649
# California           54.432649
# ...                        ...
# Wisconsin          -102.567351
# Wisconsin           -79.567351
# Wisconsin           -42.567351
# Wisconsin           -61.567351
# Wisconsin           -27.567351
#
# [4241 rows x 11 columns]

# %%
sales.Market + ' this ' +sales.Type
#these operations are faster then apply() or map() but are less flexible
# Out:
# State
# California       West this Regular
# California       West this Regular
# California       West this Regular
# California         West this Decaf
# California         West this Decaf
#                       ...
# Wisconsin     Central this Regular
# Wisconsin     Central this Regular
# Wisconsin     Central this Regular
# Wisconsin     Central this Regular
# Wisconsin     Central this Regular
# Length: 4241, dtype: object
